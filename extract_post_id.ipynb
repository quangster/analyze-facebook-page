# %%
import pandas as pd
import lib.utils as utils

# %%
num_file, posts_df = utils.read_all_file(
    folder_path='data/vebay69/raw',
    prefix='posts_',
    suffix='.csv'
)
posts_df.head(5)
# Out:
#             post_id                                               text  \
# 0  6389286101191527  Thì ra em nhỏ cris phan trữ sữa chua đầy tủ là...
# 1  6388381044615366  Nhắm đúng hôm nóng chảy mỡ thì mất điện :D\n#M...
# 2  6384990461621091                    Chả hiểu sao luôn 😀😀😀\n#Muonggg
# 3  6381191782000959                                  Ủa Bố ???\n#Panda
# 4  6380690005384470                                          🥲\n#Panda
#
#                                            post_text shared_text  \
# 0  Thì ra em nhỏ cris phan trữ sữa chua đầy tủ là...         NaN
# 1  Nhắm đúng hôm nóng chảy mỡ thì mất điện :D\n#M...         NaN
# 2                    Chả hiểu sao luôn 😀😀😀\n#Muonggg         NaN
# 3                                  Ủa Bố ???\n#Panda         NaN
# 4                                          🥲\n#Panda         NaN
#
#   original_text                 time     timestamp  \
# 0           NaN  2023-05-21 13:02:16  1.684674e+09
# ...

# %%
posts_df.drop_duplicates(subset=['post_id'], inplace=True)

# %%
posts_df['post_id'].to_csv('data/vebay69/clean/post_ids.csv', index=False)
